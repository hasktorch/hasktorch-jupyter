-- %%
:! wget -q https://vega.github.io/editor/spec/vega-lite/line.vl.json
:! if [ ! -d data ];then mkdir data ;fi
:! wget -q https://vega.github.io/editor/data/stocks.csv
:! mv stocks.csv data

-- %%
import IHaskell.Display
vegalite <$> readFile "line.vl.json"
